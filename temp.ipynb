# %%
import sys
from pathlib import Path

# Ensure project root is in sys.path
project_root = Path.cwd() if Path.cwd().name == "RAG_QnA" else Path(__file__).parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.loaders import load_pdfs
from src.chunking import print_chunk_counts_by_doc
from src.config import DATA_DIR

print(f"Project root: {project_root}")
print(f"DATA_DIR: {DATA_DIR}")

docs = load_pdfs(DATA_DIR)
print_chunk_counts_by_doc(docs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 from src.chunking import print_chunk_counts_by_doc
#       3 from src.config import DATA_DIR
# ----> 5 docs = load_pdfs(DATA_DIR)
#       6 print_chunk_counts_by_doc(docs)
#
# File d:\Portfolio Github\RAG_QnA\src\loaders.py:7, in load_pdfs(data_dir)
#       5 data_path = Path(data_dir)
#       6 if not data_path.exists():
# ----> 7     raise FileNotFoundError(f"DATA_DIR not found: {data_path}")
#       9 pdf_paths = sorted(p for p in data_path.rglob("*.pdf"))
#      10 if not pdf_paths:
#
# FileNotFoundError: DATA_DIR not found: ..\RAG Project Dataset
